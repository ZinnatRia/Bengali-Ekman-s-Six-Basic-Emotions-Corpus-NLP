# %%
# !pip install ktrain
# Out:
# Collecting ktrain
#   Downloading ktrain-0.38.0.tar.gz (25.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 44.4 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from ktrain) (3.7.2)
# Requirement already satisfied: pandas>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from ktrain) (2.0.2)
# Requirement already satisfied: fastprogress>=0.1.21 in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.0.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from ktrain) (2.31.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.3.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ktrain) (21.3)
# Collecting langdetect (from ktrain)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 54.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jieba in /opt/conda/lib/python3.10/site-packages (from ktrain) (0.42.1)
# Collecting cchardet (from ktrain)
#   Downloading cchardet-2.1.7.tar.gz (653 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 653.6/653.6 kB 48.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting chardet (from ktrain)
#   Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 19.7 MB/s eta 0:00:00
# Collecting syntok>1.3.3 (from ktrain)
#   Downloading syntok-1.4.4-py3-none-any.whl (24 kB)
# Collecting tika (from ktrain)
#   Downloading tika-2.6.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers>=4.17.0 in /opt/conda/lib/python3.10/site-packages (from ktrain) (4.33.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from ktrain) (0.1.99)
# Collecting keras_bert>=0.86.0 (from ktrain)
#   Downloading keras-bert-0.89.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting whoosh (from ktrain)
#   Downloading Whoosh-2.7.4-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.8/468.8 kB 38.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras_bert>=0.86.0->ktrain) (1.23.5)
# Collecting keras-transformer==0.40.0 (from keras_bert>=0.86.0->ktrain)
#   Downloading keras-transformer-0.40.0.tar.gz (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-pos-embd==0.13.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-pos-embd-0.13.0.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-multi-head==0.29.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-multi-head-0.29.0.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-layer-normalization==0.16.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-layer-normalization-0.16.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-position-wise-feed-forward==0.8.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-position-wise-feed-forward-0.8.0.tar.gz (4.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-embed-sim==0.10.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-embed-sim-0.10.0.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-self-attention==0.51.0 (from keras-multi-head==0.29.0->keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (9.5.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->ktrain) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->ktrain) (2023.3)
# Requirement already satisfied: regex>2016 in /opt/conda/lib/python3.10/site-packages (from syntok>1.3.3->ktrain) (2023.6.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.16.4)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (4.66.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from langdetect->ktrain) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (2023.7.22)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->ktrain) (1.11.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->ktrain) (3.1.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tika->ktrain) (68.0.0)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers>=4.17.0->ktrain) (2023.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers>=4.17.0->ktrain) (4.6.3)
# Building wheels for collected packages: ktrain, keras_bert, keras-transformer, keras-embed-sim, keras-layer-normalization, keras-multi-head, keras-pos-embd, keras-position-wise-feed-forward, keras-self-attention, cchardet, langdetect, tika
#   Building wheel for ktrain (setup.py) ... done
#   Created wheel for ktrain: filename=ktrain-0.38.0-py3-none-any.whl size=25319964 sha256=96498be0296fb076a2db0f33bda58f1634c5cfc9e66922e13b7a5bf962859494
#   Stored in directory: /root/.cache/pip/wheels/10/76/6b/5799f396ca78a8c38c7c6439a192ca88538a97cfb970946da5
#   Building wheel for keras_bert (setup.py) ... done
#   Created wheel for keras_bert: filename=keras_bert-0.89.0-py3-none-any.whl size=33501 sha256=84d3766cc3dee13db06166ff4113ebcbac839145bb7775ca73c26839b4df91b9
#   Stored in directory: /root/.cache/pip/wheels/89/0c/04/646b6fdf6375911b42c8d540a8a3fda8d5d77634e5dcbe7b26
#   Building wheel for keras-transformer (setup.py) ... done
#   Created wheel for keras-transformer: filename=keras_transformer-0.40.0-py3-none-any.whl size=12287 sha256=3700033d3f286aa2f6d7c21d4d551ac19fa39244099110070494631d0efa10d1
#   Stored in directory: /root/.cache/pip/wheels/f2/cb/22/75a0ad376129177f7c95c0d91331a18f5368fd657f4035ba7c
#   Building wheel for keras-embed-sim (setup.py) ... done
#   Created wheel for keras-embed-sim: filename=keras_embed_sim-0.10.0-py3-none-any.whl size=3943 sha256=eb3fa47c1535ceed83331726c8a6f25e1be156245611b5b8ad0f91cecdc39452
#   Stored in directory: /root/.cache/pip/wheels/82/32/c7/fd35d0d1b840a6c7cbd4343f808d10d0f7b87d271a4dbe796f
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.16.0-py3-none-any.whl size=4653 sha256=4f28759a5a447683fd0f9d086d4ae1a3c49c5dad31272e79e3c96117c1842a8a
#   Stored in directory: /root/.cache/pip/wheels/ed/3a/4b/21db23c0cc56c4b219616e181f258eb7c57d36cc5d056fae9a
#   Building wheel for keras-multi-head (setup.py) ... done
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.29.0-py3-none-any.whl size=14979 sha256=045d2c4e962904d29271dc36c8fd9b68a2b8c0eb99344133564d067729ebaafe
#   Stored in directory: /root/.cache/pip/wheels/cb/23/4b/06d7ae21714f70fcc25b48f972cc8e5e7f4b6b764a038b509d
#   Building wheel for keras-pos-embd (setup.py) ... done
#   Created wheel for keras-pos-embd: filename=keras_pos_embd-0.13.0-py3-none-any.whl size=6946 sha256=47a277d4b411441eaad7bd8410ffa079d96702cf1d4d14b2f5b699bedaed72ef
#   Stored in directory: /root/.cache/pip/wheels/78/07/1b/b1ca47b6ac338554b75c8f52c54e6a2bfbe1b07d79579979a4
#   Building wheel for keras-position-wise-feed-forward (setup.py) ... done
#   Created wheel for keras-position-wise-feed-forward: filename=keras_position_wise_feed_forward-0.8.0-py3-none-any.whl size=4968 sha256=51bf18610ad0fb606b6b3abd2543575f1125e63f6f15276ed447f7b2302ebbc1
#   Stored in directory: /root/.cache/pip/wheels/c1/6a/04/d1706a53b23b2cb5f9a0a76269bf87925daa1bca09eac01b21
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18895 sha256=f25e7e26495ab4bae8e08d2d97ee83a04da053b02dce025b735c33443741b8cf
#   Stored in directory: /root/.cache/pip/wheels/b8/f7/24/607b483144fb9c47b4ba2c5fba6b68e54aeee2d5bf6c05302e
#   Building wheel for cchardet (setup.py) ... done
#   Created wheel for cchardet: filename=cchardet-2.1.7-cp310-cp310-linux_x86_64.whl size=133763 sha256=dfc1c23aec4462525a8bbba51216acb12bf45da8461e2a978d05c2c3f9d960dd
#   Stored in directory: /root/.cache/pip/wheels/ee/e0/ab/e01326f15c59438d080b1496dbab8091e952ec72f35e3c437e
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=49c8493a8193b2d5dc3a43f5c566efa2cf5ccb30eb85936796086117ce55ba29
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32625 sha256=6d95a428edd28eac4d494550597b4012d825a9b396e7262866fb5a54f859853f
#   Stored in directory: /root/.cache/pip/wheels/5f/71/c7/b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
# Successfully built ktrain keras_bert keras-transformer keras-embed-sim keras-layer-normalization keras-multi-head keras-pos-embd keras-position-wise-feed-forward keras-self-attention cchardet langdetect tika
# Installing collected packages: whoosh, cchardet, syntok, langdetect, keras-self-attention, keras-position-wise-feed-forward, keras-pos-embd, keras-layer-normalization, keras-embed-sim, chardet, tika, keras-multi-head, keras-transformer, keras_bert, ktrain
# Successfully installed cchardet-2.1.7 chardet-5.2.0 keras-embed-sim-0.10.0 keras-layer-normalization-0.16.0 keras-multi-head-0.29.0 keras-pos-embd-0.13.0 keras-position-wise-feed-forward-0.8.0 keras-self-attention-0.51.0 keras-transformer-0.40.0 keras_bert-0.89.0 ktrain-0.38.0 langdetect-1.0.9 syntok-1.4.4 tika-2.6.0 whoosh-2.7.4

# %%
pip install bnltk
# Out:
# Collecting bnltk
#   Downloading bnltk-0.7.6-py3-none-any.whl (11 kB)
# Requirement already satisfied: keras in /opt/conda/lib/python3.10/site-packages (from bnltk) (2.12.0)
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.10/site-packages (from bnltk) (2.12.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bnltk) (1.23.5)
# Collecting sklearn (from bnltk)
#   Downloading sklearn-0.0.post10.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#
#       If the previous advice does not cover your use case, feel free to report it at
#       https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install bnlp-toolkit==4.0.0.dev4
# Out:
# Collecting bnlp-toolkit==4.0.0.dev4
#   Downloading bnlp_toolkit-4.0.0.dev4-py3-none-any.whl (22 kB)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (0.1.99)
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (4.3.2)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (3.2.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (1.23.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (1.11.2)
# Collecting sklearn-crfsuite (from bnlp-toolkit==4.0.0.dev4)
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (4.66.1)
# Collecting ftfy (from bnlp-toolkit==4.0.0.dev4)
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 3.9 MB/s eta 0:00:00
# Collecting emoji==1.7.0 (from bnlp-toolkit==4.0.0.dev4)
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 16.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (2.31.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /opt/conda/lib/python3.10/site-packages (from ftfy->bnlp-toolkit==4.0.0.dev4) (0.2.6)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim->bnlp-toolkit==4.0.0.dev4) (6.3.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk->bnlp-toolkit==4.0.0.dev4) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp-toolkit==4.0.0.dev4) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp-toolkit==4.0.0.dev4) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp-toolkit==4.0.0.dev4) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp-toolkit==4.0.0.dev4) (2023.7.22)
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite->bnlp-toolkit==4.0.0.dev4)
#   Downloading python_crfsuite-0.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.5/993.5 kB 49.1 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from sklearn-crfsuite->bnlp-toolkit==4.0.0.dev4) (0.9.0)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171033 sha256=ae08260204ce7c54607333bb5088b0e67d91699bce0b9532aa472c395e8dcd36
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# Installing collected packages: python-crfsuite, emoji, sklearn-crfsuite, ftfy, bnlp-toolkit
#   Attempting uninstall: emoji
#     Found existing installation: emoji 2.8.0
#     Uninstalling emoji-2.8.0:
#       Successfully uninstalled emoji-2.8.0
# Successfully installed bnlp-toolkit-4.0.0.dev4 emoji-1.7.0 ftfy-6.1.1 python-crfsuite-0.9.9 sklearn-crfsuite-0.3.6

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/kaggle/input/bangla-ekman-six-emotion-dataset/Dataset.xlsx")

# %%
df = df.drop('Racial Biases', axis=1)       
#axis=1 for coloum;
df = df.drop('Hatred Percentage', axis=1)
df = df.drop('Depression Percentage', axis=1)
df = df.drop('Year', axis=1)

# %%
df
# Out:
#           SL   Emotion                                               Text
# 0          1   disgust  নির্বাচনের আগের রাতে সুষ্টু শান্তিপূর্ণ ভাবে ভ...
# 1          2   disgust  জনগণ মনের আনন্দে নিজেদের ভোট কাস্ট করে দেশদ্রো...
# 2          3     angry                                   ভেজাল নির্বাচন ।
# 3          4     happy  বিএনপি ও রাজাকার সমর্থকরা হেরে গেলে দেশের জন্য...
# 4          5     angry  সূক্ষ্ম কারচুপি বলে এতদিন একটা কথার কথা ছিল, এ...
# ...      ...       ...                                                ...
# 35995  35996  surprise  ভারতের মতো একটা বিশাল দেশে এত অঙ্গরাজ্য যে সব ...
# 35996  35997  surprise                ২৪, ৫০, এমনকি কারো কারো মতে ৬০ জন।
# 35997  35998  surprise  এদের মধ্য থেকে ২৭ জনকে রাজা বিয়ে দিয়েছিল চন্দ্...
# 35998  35999  surprise  ওয়াকফের শাব্দিক অর্থ কোনো কিছু আটকে রাখা, উৎসর...
# 35999  36000  surprise   তৃণমূলের সাবেক মন্ত্রী শুভেন্দু সম্প্রতি মমতা...
#
# [36000 rows x 3 columns]

# %%
from bnlp import CleanText

clean_text = CleanText(
   fix_unicode=True,
   unicode_norm=True,
   unicode_norm_form="NFKC",
   remove_url=False,
   remove_email=False,
   remove_emoji=False,
   remove_number=False,
   remove_digits=False,
   remove_punct=False,
   replace_with_url="",
   replace_with_email="",
   replace_with_number="",
   replace_with_digit="",
   replace_with_punct = ""
)

# Apply the cleaning process to the 'Text' column
#df['cleaned_text'] = df['Text'].apply(clean_text)

# Print the cleaned text in the 'cleaned_text' column
#print(df['cleaned_text'])
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
for i in range(0,df.shape[0]):
    
    text =  clean_text(df['Text'][i])
    df['Text'][i] = text

# %%
rows_to_display = [0, 1, 2]  # Choose the row indices you want to display

for row_index in rows_to_display:
    print(f"Row {row_index} - Original Text: {df.loc[row_index, 'Text']}")
    #print(f"Row {row_index} - Cleaned Text : {df.loc[row_index, 'cleaned_text']}\n")
# Out:
# Row 0 - Original Text: নির্বাচনের আগের রাতে সুষ্টু শান্তিপূর্ণ ভাবে ভোট বাক্স ভর্তি হলে যা হয়
# Row 1 - Original Text: জনগণ মনের আনন্দে নিজেদের ভোট কাস্ট করে দেশদ্রোহী পেট্রল বোমারুদের নির্বাচনী ফলাফল থেকে উচ্ছেদ করেছে, ইহাই জনগনের মূল আনন্দ, জয় বাংলা!
# Row 2 - Original Text: ভেজাল নির্বাচন ।

# %%
import re


# Define a function to check for special characters
def has_special_characters(Text):
    # Define a pattern to match special characters
    pattern = r'[\&\#\$\~\%\^\*\[\]\{\}]'
    # Use re.search() to check if the pattern is found in the text
    if re.search(pattern, Text):
        return True
    else:
        return False

# Apply the function to the 'Text' column to create a boolean mask
df['has_special_chars'] = df['Text'].apply(has_special_characters)

# Print rows where special characters are present
rows_with_special_chars = df[df['has_special_chars']]
print("Rows with Special Characters:")
print(rows_with_special_chars)


print("There is no special characters. So we dont need to work with special characters.")
# Out:
# Rows with Special Characters:
#           SL   Emotion                                               Text  \
# 23        24     happy  ভাল নির্বাচনে 100 % ভোটারদের উপস্থিতি থাকলে আর...
# 99       100     happy         ১০০% খাটি কথা, হাজার কথার এক কথা। ধন্যবাদ।
# 406      407  surprise  আওয়ামীলীগ সরকারের কর্মকাণ্ডে জনগণ ১০০% সন্তুষ...
# 499      500     happy  নাইট শিফটে ভোটের বাক্স ভরেও মাত্র ৯০%? অবিলম্ব...
# 509      510   disgust  আমার ভোটও আমি দিতে পারি নাই !! সুষ্টভাবে কোন র...
# ...      ...       ...                                                ...
# 35102  35103   disgust  এটাকে ৮০% জনতার ভোট আওয়ামীলীগের পক্ষে মনে না ...
# 35543  35544      fear  আসলে হানিফ দাদার ভাষায় ইসি যে আওয়ামী লিগের প...
# 35641  35642     happy  মুক্তি কে জিগাছ করা হোক কে বাঙ্গছে,,,,,,,তার ম...
# 35767  35768  surprise  ৬৪% নারী কর্মী দালালদের টাকা দিয়ে মধ্যপ্রাচ্য...
# 35924  35925  surprise  ৬৪% নারী কর্মী দালালদের টাকা দিয়ে মধ্যপ্রাচ্য...
#
#        has_special_chars
# 23                  True
# 99                  True
# 406                 True
# 499                 True
# 509                 True
# ...                  ...
# 35102               True
# 35543               True
# 35641               True
# 35767               True
# 35924               True
#
# [426 rows x 4 columns]
# There is no special characters. So we dont need to work with special characters.

# %%
df = df.drop('has_special_chars', axis=1)
df
# Out:
#           SL   Emotion                                               Text
# 0          1   disgust  নির্বাচনের আগের রাতে সুষ্টু শান্তিপূর্ণ ভাবে ভ...
# 1          2   disgust  জনগণ মনের আনন্দে নিজেদের ভোট কাস্ট করে দেশদ্রো...
# 2          3     angry                                   ভেজাল নির্বাচন ।
# 3          4     happy  বিএনপি ও রাজাকার সমর্থকরা হেরে গেলে দেশের জন্য...
# 4          5     angry  সূক্ষ্ম কারচুপি বলে এতদিন একটা কথার কথা ছিল, এ...
# ...      ...       ...                                                ...
# 35995  35996  surprise  ভারতের মতো একটা বিশাল দেশে এত অঙ্গরাজ্য যে সব ...
# 35996  35997  surprise                ২৪, ৫০, এমনকি কারো কারো মতে ৬০ জন।
# 35997  35998  surprise  এদের মধ্য থেকে ২৭ জনকে রাজা বিয়ে দিয়েছিল চন্...
# 35998  35999  surprise  ওয়াকফের শাব্দিক অর্থ কোনো কিছু আটকে রাখা, উৎস...
# 35999  36000  surprise   তৃণমূলের সাবেক মন্ত্রী শুভেন্দু সম্প্রতি মমতা...
#
# [36000 rows x 3 columns]

# %%
text = df['Text'].values.tolist()
label = df['Emotion'].tolist()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(text , label, test_size=0.2, random_state=42)

# %%
import ktrain
from ktrain import text
MODEL_NAME = 'sagorsarker/bangla-bert-base'
t = text.Transformer(MODEL_NAME, maxlen=500)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/491 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/660M [00:00<?, ?B/s]

# %%
trn = t.preprocess_train(X_train, y_train)
val = t.preprocess_test(X_test, y_test)
# Out:
# preprocessing train...
# language: bn
# train sequence lengths:
# 	mean : 16
# 	95percentile : 44
# 	99percentile : 67
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/2.24M [00:00<?, ?B/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Is Multi-Label? False
# preprocessing test...
# language: bn
# test sequence lengths:
# 	mean : 16
# 	95percentile : 43
# 	99percentile : 68
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
model = t.get_classifier()

# %%
learner = ktrain.get_learner(model, train_data=trn, val_data=val, batch_size=12)

# %%
history = learner.fit_onecycle(2e-5, 5)
# Out:
# begin training using onecycle policy with max lr of 2e-05...
# Epoch 1/5
# 2400/2400 [==============================] - 2176s 896ms/step - loss: 1.4423 - accuracy: 0.4343 - val_loss: 0.9692 - val_accuracy: 0.6572
# Epoch 2/5
# 2400/2400 [==============================] - 2143s 893ms/step - loss: 0.7323 - accuracy: 0.7514 - val_loss: 0.6392 - val_accuracy: 0.7910
# Epoch 3/5
# 2400/2400 [==============================] - 2143s 893ms/step - loss: 0.4338 - accuracy: 0.8581 - val_loss: 0.5296 - val_accuracy: 0.8400
# Epoch 4/5
# 2400/2400 [==============================] - 2143s 893ms/step - loss: 0.2276 - accuracy: 0.9255 - val_loss: 0.5103 - val_accuracy: 0.8628
# Epoch 5/5
# 2400/2400 [==============================] - 2143s 893ms/step - loss: 0.1230 - accuracy: 0.9557 - val_loss: 0.5252 - val_accuracy: 0.8651

# %%
learner.validate(class_names=t.get_classes())
# Out:
# 225/225 [==============================] - 155s 677ms/step
#               precision    recall  f1-score   support
#
#        angry       0.84      0.85      0.85      1226
#      disgust       0.87      0.89      0.88      1188
#         fear       0.88      0.92      0.90      1129
#        happy       0.93      0.87      0.90      1246
#          sad       0.80      0.75      0.77      1244
#     surprise       0.88      0.92      0.90      1167
#
#     accuracy                           0.87      7200
#    macro avg       0.87      0.87      0.87      7200
# weighted avg       0.87      0.87      0.86      7200
# array([[1048,   46,   30,   11,   73,   18],
#        [  56, 1055,   13,   14,   30,   20],
#        [  16,    8, 1040,    4,   46,   15],
#        [  36,   15,   15, 1081,   60,   39],
#        [  76,   69,   61,   47,  934,   57],
#        [  19,   24,   17,    8,   28, 1071]])

# %%
PlotGraph(history)
