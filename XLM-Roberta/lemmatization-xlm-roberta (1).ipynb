# %%
# !pip install ktrain
# Out:
# Collecting ktrain
#   Downloading ktrain-0.39.0.tar.gz (25.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 8.5 MB/s eta 0:00:00:00:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from ktrain) (3.7.3)
# Requirement already satisfied: pandas>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from ktrain) (2.0.3)
# Requirement already satisfied: fastprogress>=0.1.21 in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.0.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from ktrain) (2.31.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.3.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ktrain) (21.3)
# Collecting langdetect (from ktrain)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 52.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jieba in /opt/conda/lib/python3.10/site-packages (from ktrain) (0.42.1)
# Requirement already satisfied: charset-normalizer in /opt/conda/lib/python3.10/site-packages (from ktrain) (3.2.0)
# Collecting chardet (from ktrain)
#   Obtaining dependency information for chardet from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting syntok>1.3.3 (from ktrain)
#   Downloading syntok-1.4.4-py3-none-any.whl (24 kB)
# Collecting tika (from ktrain)
#   Downloading tika-2.6.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers>=4.17.0 in /opt/conda/lib/python3.10/site-packages (from ktrain) (4.35.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from ktrain) (0.1.99)
# Collecting keras_bert>=0.86.0 (from ktrain)
#   Downloading keras-bert-0.89.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting whoosh (from ktrain)
#   Downloading Whoosh-2.7.4-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.8/468.8 kB 31.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras_bert>=0.86.0->ktrain) (1.24.3)
# Collecting keras-transformer==0.40.0 (from keras_bert>=0.86.0->ktrain)
#   Downloading keras-transformer-0.40.0.tar.gz (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-pos-embd==0.13.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-pos-embd-0.13.0.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-multi-head==0.29.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-multi-head-0.29.0.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-layer-normalization==0.16.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-layer-normalization-0.16.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-position-wise-feed-forward==0.8.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-position-wise-feed-forward-0.8.0.tar.gz (4.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-embed-sim==0.10.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-embed-sim-0.10.0.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-self-attention==0.51.0 (from keras-multi-head==0.29.0->keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->ktrain) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->ktrain) (2023.3)
# Requirement already satisfied: regex>2016 in /opt/conda/lib/python3.10/site-packages (from syntok>1.3.3->ktrain) (2023.8.8)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.17.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (6.0.1)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (4.66.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from langdetect->ktrain) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (2023.7.22)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->ktrain) (1.11.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->ktrain) (3.2.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tika->ktrain) (68.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers>=4.17.0->ktrain) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers>=4.17.0->ktrain) (4.5.0)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 15.4 MB/s eta 0:00:00
# Building wheels for collected packages: ktrain, keras_bert, keras-transformer, keras-embed-sim, keras-layer-normalization, keras-multi-head, keras-pos-embd, keras-position-wise-feed-forward, keras-self-attention, langdetect, tika
#   Building wheel for ktrain (setup.py) ... done
#   Created wheel for ktrain: filename=ktrain-0.39.0-py3-none-any.whl size=25319738 sha256=5d4b327f4b99c375486eaf19d02461d870afce4c954e721c02ea1803305bcd24
#   Stored in directory: /root/.cache/pip/wheels/98/fd/0a/ef6252223f3d2c49b06d18e71c74caa43bbf4c64a8c183a46e
#   Building wheel for keras_bert (setup.py) ... done
#   Created wheel for keras_bert: filename=keras_bert-0.89.0-py3-none-any.whl size=33499 sha256=20f1ab55799e6397ff5faa7c45665b5da0666a4751f68d536123485efb81826b
#   Stored in directory: /root/.cache/pip/wheels/89/0c/04/646b6fdf6375911b42c8d540a8a3fda8d5d77634e5dcbe7b26
#   Building wheel for keras-transformer (setup.py) ... done
#   Created wheel for keras-transformer: filename=keras_transformer-0.40.0-py3-none-any.whl size=12285 sha256=258cf2b35b12c4ac1e8312cbbba2255d7a677aaf5748e9b90cc772ad6d4ede71
#   Stored in directory: /root/.cache/pip/wheels/f2/cb/22/75a0ad376129177f7c95c0d91331a18f5368fd657f4035ba7c
#   Building wheel for keras-embed-sim (setup.py) ... done
#   Created wheel for keras-embed-sim: filename=keras_embed_sim-0.10.0-py3-none-any.whl size=3945 sha256=61c51bc471309c41fea79a95ed22fba922fd822d89bc3e181bfd2313c8dfe3ed
#   Stored in directory: /root/.cache/pip/wheels/82/32/c7/fd35d0d1b840a6c7cbd4343f808d10d0f7b87d271a4dbe796f
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.16.0-py3-none-any.whl size=4654 sha256=70c7281058a89bb34553d10218a682b719ad9e3edb2bc1ab1ff3622a814d16ce
#   Stored in directory: /root/.cache/pip/wheels/ed/3a/4b/21db23c0cc56c4b219616e181f258eb7c57d36cc5d056fae9a
#   Building wheel for keras-multi-head (setup.py) ... done
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.29.0-py3-none-any.whl size=14977 sha256=50d092df4d54ab48cd475f8c19cee0d586d44dfa17bc4182797c0ee100493a6b
#   Stored in directory: /root/.cache/pip/wheels/cb/23/4b/06d7ae21714f70fcc25b48f972cc8e5e7f4b6b764a038b509d
#   Building wheel for keras-pos-embd (setup.py) ... done
#   Created wheel for keras-pos-embd: filename=keras_pos_embd-0.13.0-py3-none-any.whl size=6945 sha256=840c194991ddc6bebe006869baf00dfd7e5e00f843d609294aa1b8e0cc7f16c9
#   Stored in directory: /root/.cache/pip/wheels/78/07/1b/b1ca47b6ac338554b75c8f52c54e6a2bfbe1b07d79579979a4
#   Building wheel for keras-position-wise-feed-forward (setup.py) ... done
#   Created wheel for keras-position-wise-feed-forward: filename=keras_position_wise_feed_forward-0.8.0-py3-none-any.whl size=4969 sha256=f51cfb9ce5fcd6f29a98ab1796f27f3c81022ca7eea2919f695da95da4d1ca6b
#   Stored in directory: /root/.cache/pip/wheels/c1/6a/04/d1706a53b23b2cb5f9a0a76269bf87925daa1bca09eac01b21
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18895 sha256=3615ef90eff3fb94cebdcb803ff0a730db869053f65d8b34eb44d1a1ff45ab2a
#   Stored in directory: /root/.cache/pip/wheels/b8/f7/24/607b483144fb9c47b4ba2c5fba6b68e54aeee2d5bf6c05302e
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=3f4339a6b06b41cb765623f197e93c9e67c515db3a2657f5fd64fdc11b4a3462
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32621 sha256=1a9fbe5588fcde48dbc48df75b2b2faebbd6dbcce0c895ca5fd024b986ab2b81
#   Stored in directory: /root/.cache/pip/wheels/5f/71/c7/b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
# Successfully built ktrain keras_bert keras-transformer keras-embed-sim keras-layer-normalization keras-multi-head keras-pos-embd keras-position-wise-feed-forward keras-self-attention langdetect tika
# Installing collected packages: whoosh, syntok, langdetect, keras-self-attention, keras-position-wise-feed-forward, keras-pos-embd, keras-layer-normalization, keras-embed-sim, chardet, tika, keras-multi-head, keras-transformer, keras_bert, ktrain
# Successfully installed chardet-5.2.0 keras-embed-sim-0.10.0 keras-layer-normalization-0.16.0 keras-multi-head-0.29.0 keras-pos-embd-0.13.0 keras-position-wise-feed-forward-0.8.0 keras-self-attention-0.51.0 keras-transformer-0.40.0 keras_bert-0.89.0 ktrain-0.39.0 langdetect-1.0.9 syntok-1.4.4 tika-2.6.0 whoosh-2.7.4

# %%
pip install bnltk
# Out:
# Collecting bnltk
#   Downloading bnltk-0.7.6-py3-none-any.whl (11 kB)
# Requirement already satisfied: keras in /opt/conda/lib/python3.10/site-packages (from bnltk) (2.13.1)
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.10/site-packages (from bnltk) (2.13.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bnltk) (1.24.3)
# Collecting sklearn (from bnltk)
#   Downloading sklearn-0.0.post11.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#
#       If the previous advice does not cover your use case, feel free to report it at
#       https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install bnlp-toolkit==4.0.0.dev4
# Out:
# Collecting bnlp-toolkit==4.0.0.dev4
#   Obtaining dependency information for bnlp-toolkit==4.0.0.dev4 from https://files.pythonhosted.org/packages/c7/8b/259efbf7f3fc1afb188a83a3378e35d1d39ef6750275ca24c3040c6060d1/bnlp_toolkit-4.0.0.dev4-py3-none-any.whl.metadata
#   Downloading bnlp_toolkit-4.0.0.dev4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (0.1.99)
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (4.3.2)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (3.2.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (1.24.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (1.11.3)
# Collecting sklearn-crfsuite (from bnlp-toolkit==4.0.0.dev4)
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (4.66.1)
# Collecting ftfy (from bnlp-toolkit==4.0.0.dev4)
#   Obtaining dependency information for ftfy from https://files.pythonhosted.org/packages/91/f8/dfa32d06cfcbdb76bc46e0f5d69c537de33f4cedb1a15cd4746ab45a6a26/ftfy-6.1.3-py3-none-any.whl.metadata
#   Downloading ftfy-6.1.3-py3-none-any.whl.metadata (6.2 kB)
# Collecting emoji==1.7.0 (from bnlp-toolkit==4.0.0.dev4)
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 4.2 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from bnlp-toolkit==4.0.0.dev4) (2.31.0)
# Collecting wcwidth<0.3.0,>=0.2.12 (from ftfy->bnlp-toolkit==4.0.0.dev4)
#   Obtaining dependency information for wcwidth<0.3.0,>=0.2.12 from https://files.pythonhosted.org/packages/31/b1/a59de0ad3aabb17523a39804f4c6df3ae87ead053a4e25362ae03d73d03a/wcwidth-0.2.12-py2.py3-none-any.whl.metadata
#   Downloading wcwidth-0.2.12-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim->bnlp-toolkit==4.0.0.dev4) (6.3.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk->bnlp-toolkit==4.0.0.dev4) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp-toolkit==4.0.0.dev4) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp-toolkit==4.0.0.dev4) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp-toolkit==4.0.0.dev4) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp-toolkit==4.0.0.dev4) (2023.7.22)
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite->bnlp-toolkit==4.0.0.dev4)
#   Downloading python_crfsuite-0.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.5/993.5 kB 25.9 MB/s eta 0:00:0000:01
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from sklearn-crfsuite->bnlp-toolkit==4.0.0.dev4) (0.9.0)
# Downloading bnlp_toolkit-4.0.0.dev4-py3-none-any.whl (22 kB)
# Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 5.5 MB/s eta 0:00:00
# Downloading wcwidth-0.2.12-py2.py3-none-any.whl (34 kB)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171033 sha256=1f252a15b88da5b6f360854203654f17a7ad7d15aa7fee413fd6ae992367d0b1
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# Installing collected packages: wcwidth, python-crfsuite, emoji, sklearn-crfsuite, ftfy, bnlp-toolkit
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.6
#     Uninstalling wcwidth-0.2.6:
#       Successfully uninstalled wcwidth-0.2.6
#   Attempting uninstall: emoji
#     Found existing installation: emoji 2.8.0
#     Uninstalling emoji-2.8.0:
#       Successfully uninstalled emoji-2.8.0
# Successfully installed bnlp-toolkit-4.0.0.dev4 emoji-1.7.0 ftfy-6.1.3 python-crfsuite-0.9.9 sklearn-crfsuite-0.3.6 wcwidth-0.2.12

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/kaggle/input/bangla-ekman-six-emotion-dataset/Dataset.xlsx")

# %%
df = df.drop('Racial Biases', axis=1)       
#axis=1 for coloum;
df = df.drop('Hatred Percentage', axis=1)
df = df.drop('Depression Percentage', axis=1)
df = df.drop('Year', axis=1)

# %%
df
# Out:
#           SL   Emotion                                               Text
# 0          1   disgust  নির্বাচনের আগের রাতে সুষ্টু শান্তিপূর্ণ ভাবে ভ...
# 1          2   disgust  জনগণ মনের আনন্দে নিজেদের ভোট কাস্ট করে দেশদ্রো...
# 2          3     angry                                   ভেজাল নির্বাচন ।
# 3          4     happy  বিএনপি ও রাজাকার সমর্থকরা হেরে গেলে দেশের জন্য...
# 4          5     angry  সূক্ষ্ম কারচুপি বলে এতদিন একটা কথার কথা ছিল, এ...
# ...      ...       ...                                                ...
# 35995  35996  surprise  ভারতের মতো একটা বিশাল দেশে এত অঙ্গরাজ্য যে সব ...
# 35996  35997  surprise                ২৪, ৫০, এমনকি কারো কারো মতে ৬০ জন।
# 35997  35998  surprise  এদের মধ্য থেকে ২৭ জনকে রাজা বিয়ে দিয়েছিল চন্দ্...
# 35998  35999  surprise  ওয়াকফের শাব্দিক অর্থ কোনো কিছু আটকে রাখা, উৎসর...
# 35999  36000  surprise   তৃণমূলের সাবেক মন্ত্রী শুভেন্দু সম্প্রতি মমতা...
#
# [36000 rows x 3 columns]

# %%
from bnlp import CleanText

clean_text = CleanText(
   fix_unicode=True,
   unicode_norm=True,
   unicode_norm_form="NFKC",
   remove_url=False,
   remove_email=False,
   remove_emoji=False,
   remove_number=False,
   remove_digits=False,
   remove_punct=False,
   replace_with_url="",
   replace_with_email="",
   replace_with_number="",
   replace_with_digit="",
   replace_with_punct = ""
)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
for i in range(0,df.shape[0]):
    
    text =  clean_text(df['Text'][i])
    df['Text'][i] = text

# %%
rows_to_display = [0, 1, 2]  # Choose the row indices you want to display

for row_index in rows_to_display:
    print(f"Row {row_index} - Original Text: {df.loc[row_index, 'Text']}")
    #print(f"Row {row_index} - Cleaned Text : {df.loc[row_index, 'cleaned_text']}\n")
# Out:
# Row 0 - Original Text: নির্বাচনের আগের রাতে সুষ্টু শান্তিপূর্ণ ভাবে ভোট বাক্স ভর্তি হলে যা হয়
# Row 1 - Original Text: জনগণ মনের আনন্দে নিজেদের ভোট কাস্ট করে দেশদ্রোহী পেট্রল বোমারুদের নির্বাচনী ফলাফল থেকে উচ্ছেদ করেছে, ইহাই জনগনের মূল আনন্দ, জয় বাংলা!
# Row 2 - Original Text: ভেজাল নির্বাচন ।

# %%
import re


# Define a function to check for special characters
def has_special_characters(Text):
    # Define a pattern to match special characters
    pattern = r'[\&\#\$\~\%\^\*\[\]\{\}]'
    # Use re.search() to check if the pattern is found in the text
    if re.search(pattern, Text):
        return True
    else:
        return False

# Apply the function to the 'Text' column to create a boolean mask
df['has_special_chars'] = df['Text'].apply(has_special_characters)

# Print rows where special characters are present
rows_with_special_chars = df[df['has_special_chars']]
print("Rows with Special Characters:")
print(rows_with_special_chars)
# Out:
# Rows with Special Characters:
#           SL   Emotion                                               Text  \
# 23        24     happy  ভাল নির্বাচনে 100 % ভোটারদের উপস্থিতি থাকলে আর...
# 99       100     happy         ১০০% খাটি কথা, হাজার কথার এক কথা। ধন্যবাদ।
# 406      407  surprise  আওয়ামীলীগ সরকারের কর্মকাণ্ডে জনগণ ১০০% সন্তুষ...
# 499      500     happy  নাইট শিফটে ভোটের বাক্স ভরেও মাত্র ৯০%? অবিলম্ব...
# 509      510   disgust  আমার ভোটও আমি দিতে পারি নাই !! সুষ্টভাবে কোন র...
# ...      ...       ...                                                ...
# 35102  35103   disgust  এটাকে ৮০% জনতার ভোট আওয়ামীলীগের পক্ষে মনে না ...
# 35543  35544      fear  আসলে হানিফ দাদার ভাষায় ইসি যে আওয়ামী লিগের প...
# 35641  35642     happy  মুক্তি কে জিগাছ করা হোক কে বাঙ্গছে,,,,,,,তার ম...
# 35767  35768  surprise  ৬৪% নারী কর্মী দালালদের টাকা দিয়ে মধ্যপ্রাচ্য...
# 35924  35925  surprise  ৬৪% নারী কর্মী দালালদের টাকা দিয়ে মধ্যপ্রাচ্য...
#
#        has_special_chars
# 23                  True
# 99                  True
# 406                 True
# 499                 True
# 509                 True
# ...                  ...
# 35102               True
# 35543               True
# 35641               True
# 35767               True
# 35924               True
#
# [426 rows x 4 columns]

# %%
pip install nlu
# Out:
# Collecting nlu
#   Obtaining dependency information for nlu from https://files.pythonhosted.org/packages/3d/32/7d92bb42e5089abb90d23e01476bcb91f7db0ed352ef9378a96760acbcad/nlu-5.1.0-py3-none-any.whl.metadata
#   Downloading nlu-5.1.0-py3-none-any.whl.metadata (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 2.7 MB/s eta 0:00:00a 0:00:01
# Collecting dataclasses (from nlu)
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from nlu) (1.24.3)
# Requirement already satisfied: pandas>=1.3.5 in /opt/conda/lib/python3.10/site-packages (from nlu) (2.0.3)
# Requirement already satisfied: pyarrow>=0.16.0 in /opt/conda/lib/python3.10/site-packages (from nlu) (11.0.0)
# Collecting spark-nlp>=5.0.2 (from nlu)
#   Obtaining dependency information for spark-nlp>=5.0.2 from https://files.pythonhosted.org/packages/7e/11/8d8adda6e025d201d3988efe94caf18d8b427f04f378060662f5312b1b40/spark_nlp-5.1.4-py2.py3-none-any.whl.metadata
#   Downloading spark_nlp-5.1.4-py2.py3-none-any.whl.metadata (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3.5->nlu) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3.5->nlu) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3.5->nlu) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->nlu) (1.16.0)
# Downloading nlu-5.1.0-py3-none-any.whl (655 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 656.0/656.0 kB 15.4 MB/s eta 0:00:0000:01
# Downloading spark_nlp-5.1.4-py2.py3-none-any.whl (540 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.7/540.7 kB 35.5 MB/s eta 0:00:00
# Installing collected packages: spark-nlp, dataclasses, nlu
# Successfully installed dataclasses-0.6 nlu-5.1.0 spark-nlp-5.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyspark==3.0.2
# Out:
# Collecting pyspark==3.0.2
#   Downloading pyspark-3.0.2.tar.gz (204.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.8/204.8 MB 5.5 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting py4j==0.10.9 (from pyspark==3.0.2)
#   Downloading py4j-0.10.9-py2.py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.6/198.6 kB 18.2 MB/s eta 0:00:00
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.0.2-py2.py3-none-any.whl size=205186667 sha256=d15d7a60522c9a773f96a77e86f8a9e8823d46086ea2328831e1c3e636db8c67
#   Stored in directory: /root/.cache/pip/wheels/fb/cd/19/98b6d82b551dbb40136e297f1a86112dba87dfe0d93c9085ab
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
#   Attempting uninstall: py4j
#     Found existing installation: py4j 0.10.9.7
#     Uninstalling py4j-0.10.9.7:
#       Successfully uninstalled py4j-0.10.9.7
# Successfully installed py4j-0.10.9 pyspark-3.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import nlu

# %%
df
# Out:
#           SL   Emotion                                               Text  \
# 0          1   disgust  নির্বাচনের আগের রাতে সুষ্টু শান্তিপূর্ণ ভাবে ভ...
# 1          2   disgust  জনগণ মনের আনন্দে নিজেদের ভোট কাস্ট করে দেশদ্রো...
# 2          3     angry                                   ভেজাল নির্বাচন ।
# 3          4     happy  বিএনপি ও রাজাকার সমর্থকরা হেরে গেলে দেশের জন্য...
# 4          5     angry  সূক্ষ্ম কারচুপি বলে এতদিন একটা কথার কথা ছিল, এ...
# ...      ...       ...                                                ...
# 35995  35996  surprise  ভারতের মতো একটা বিশাল দেশে এত অঙ্গরাজ্য যে সব ...
# 35996  35997  surprise                ২৪, ৫০, এমনকি কারো কারো মতে ৬০ জন।
# 35997  35998  surprise  এদের মধ্য থেকে ২৭ জনকে রাজা বিয়ে দিয়েছিল চন্...
# 35998  35999  surprise  ওয়াকফের শাব্দিক অর্থ কোনো কিছু আটকে রাখা, উৎস...
# 35999  36000  surprise   তৃণমূলের সাবেক মন্ত্রী শুভেন্দু সম্প্রতি মমতা...
#
#        has_special_chars
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ...                  ...
# 35995              False
# 35996              False
# 35997              False
# 35998              False
# 35999              False
#
# [36000 rows x 4 columns]

# %%
df = df.drop('has_special_chars', axis=1)
df
# Out:
#           SL   Emotion                                               Text
# 0          1   disgust  নির্বাচনের আগের রাতে সুষ্টু শান্তিপূর্ণ ভাবে ভ...
# 1          2   disgust  জনগণ মনের আনন্দে নিজেদের ভোট কাস্ট করে দেশদ্রো...
# 2          3     angry                                   ভেজাল নির্বাচন ।
# 3          4     happy  বিএনপি ও রাজাকার সমর্থকরা হেরে গেলে দেশের জন্য...
# 4          5     angry  সূক্ষ্ম কারচুপি বলে এতদিন একটা কথার কথা ছিল, এ...
# ...      ...       ...                                                ...
# 35995  35996  surprise  ভারতের মতো একটা বিশাল দেশে এত অঙ্গরাজ্য যে সব ...
# 35996  35997  surprise                ২৪, ৫০, এমনকি কারো কারো মতে ৬০ জন।
# 35997  35998  surprise  এদের মধ্য থেকে ২৭ জনকে রাজা বিয়ে দিয়েছিল চন্...
# 35998  35999  surprise  ওয়াকফের শাব্দিক অর্থ কোনো কিছু আটকে রাখা, উৎস...
# 35999  36000  surprise   তৃণমূলের সাবেক মন্ত্রী শুভেন্দু সম্প্রতি মমতা...
#
# [36000 rows x 3 columns]

# %%
from bnlp import NLTKTokenizer

bnltk = NLTKTokenizer()

def tokenize_text(Text):
    word_tokens = bnltk.word_tokenize(Text)
    sentence_tokens = bnltk.sentence_tokenize(Text)
    return word_tokens, sentence_tokens

# Apply tokenization to the 'Text' column
df[['word_tokens', 'sentence_tokens']] = df['Text'].apply(tokenize_text).apply(pd.Series)

# Print the tokenized data for a few specific rows
rows_to_display = [0, 1, 2,3,4]  # Choose the row indices you want to display

for row_index in rows_to_display:
   # print(f"Row {row_index} - Original Text: {df.loc[row_index, 'Text']}")
    print(f"Row {row_index} - Word Tokens: {df.loc[row_index, 'word_tokens']}")
    print(f"Row {row_index} - Sentence Tokens: {df.loc[row_index, 'sentence_tokens']}\n")
# Out:
# Row 0 - Word Tokens: ['নির্বাচনের', 'আগের', 'রাতে', 'সুষ্টু', 'শান্তিপূর্ণ', 'ভাবে', 'ভোট', 'বাক্স', 'ভর্তি', 'হলে', 'যা', 'হয়']
# Row 0 - Sentence Tokens: ['নির্বাচনের আগের রাতে সুষ্টু শান্তিপূর্ণ ভাবে ভোট বাক্স ভর্তি হলে যা হয়']
#
# Row 1 - Word Tokens: ['জনগণ', 'মনের', 'আনন্দে', 'নিজেদের', 'ভোট', 'কাস্ট', 'করে', 'দেশদ্রোহী', 'পেট্রল', 'বোমারুদের', 'নির্বাচনী', 'ফলাফল', 'থেকে', 'উচ্ছেদ', 'করেছে', ',', 'ইহাই', 'জনগনের', 'মূল', 'আনন্দ', ',', 'জয়', 'বাংলা', '!']
# Row 1 - Sentence Tokens: ['জনগণ মনের আনন্দে নিজেদের ভোট কাস্ট করে দেশদ্রোহী পেট্রল বোমারুদের নির্বাচনী ফলাফল থেকে উচ্ছেদ করেছে, ইহাই জনগনের মূল আনন্দ, জয় বাংলা!']
#
# Row 2 - Word Tokens: ['ভেজাল', 'নির্বাচন', '।']
# Row 2 - Sentence Tokens: ['ভেজাল নির্বাচন ।']
#
# Row 3 - Word Tokens: ['বিএনপি', 'ও', 'রাজাকার', 'সমর্থকরা', 'হেরে', 'গেলে', 'দেশের', 'জন্য', 'ভাল', ',', 'তাতে', 'আমিও', 'সন্তুষ্টি', 'খুঁজে', 'পাই', '।']
# Row 3 - Sentence Tokens: ['বিএনপি ও রাজাকার সমর্থকরা হেরে গেলে দেশের জন্য ভাল, তাতে আমিও সন্তুষ্টি খুঁজে পাই।']
#
# Row 4 - Word Tokens: ['সূক্ষ্ম', 'কারচুপি', 'বলে', 'এতদিন', 'একটা', 'কথার', 'কথা', 'ছিল', ',', 'এবার', 'তা', 'বাস্তব', 'রূপ', 'পেয়েছে', '।']
# Row 4 - Sentence Tokens: ['সূক্ষ্ম কারচুপি বলে এতদিন একটা কথার কথা ছিল, এবার তা বাস্তব রূপ পেয়েছে।']

# %%
df = df.drop('sentence_tokens', axis=1)
df
# Out:
#           SL   Emotion                                               Text  \
# 0          1   disgust  নির্বাচনের আগের রাতে সুষ্টু শান্তিপূর্ণ ভাবে ভ...
# 1          2   disgust  জনগণ মনের আনন্দে নিজেদের ভোট কাস্ট করে দেশদ্রো...
# 2          3     angry                                   ভেজাল নির্বাচন ।
# 3          4     happy  বিএনপি ও রাজাকার সমর্থকরা হেরে গেলে দেশের জন্য...
# 4          5     angry  সূক্ষ্ম কারচুপি বলে এতদিন একটা কথার কথা ছিল, এ...
# ...      ...       ...                                                ...
# 35995  35996  surprise  ভারতের মতো একটা বিশাল দেশে এত অঙ্গরাজ্য যে সব ...
# 35996  35997  surprise                ২৪, ৫০, এমনকি কারো কারো মতে ৬০ জন।
# 35997  35998  surprise  এদের মধ্য থেকে ২৭ জনকে রাজা বিয়ে দিয়েছিল চন্...
# 35998  35999  surprise  ওয়াকফের শাব্দিক অর্থ কোনো কিছু আটকে রাখা, উৎস...
# 35999  36000  surprise   তৃণমূলের সাবেক মন্ত্রী শুভেন্দু সম্প্রতি মমতা...
#
#                                              word_tokens
# 0      [নির্বাচনের, আগের, রাতে, সুষ্টু, শান্তিপূর্ণ, ...
# 1      [জনগণ, মনের, আনন্দে, নিজেদের, ভোট, কাস্ট, করে,...
# 2                                   [ভেজাল, নির্বাচন, ।]
# 3      [বিএনপি, ও, রাজাকার, সমর্থকরা, হেরে, গেলে, দেশ...
# 4      [সূক্ষ্ম, কারচুপি, বলে, এতদিন, একটা, কথার, কথা...
# ...                                                  ...
# 35995  [ভারতের, মতো, একটা, বিশাল, দেশে, এত, অঙ্গরাজ্য...
# 35996  [২৪, ,, ৫০, ,, এমনকি, কারো, কারো, মতে, ৬০, জন, ।]
# 35997  [এদের, মধ্য, থেকে, ২৭, জনকে, রাজা, বিয়ে, দিয়...
# 35998  [ওয়াকফের, শাব্দিক, অর্থ, কোনো, কিছু, আটকে, রা...
# 35999  [তৃণমূলের, সাবেক, মন্ত্রী, শুভেন্দু, সম্প্রতি,...
#
# [36000 rows x 4 columns]

# %%
# !pip install BnLemma
# Out:
# Collecting BnLemma
#   Downloading BnLemma-2.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: BnLemma
# Successfully installed BnLemma-2.1

# %%
pip install git+https://github.com/banglakit/lemmatizer.git
# Out:
# Collecting git+https://github.com/banglakit/lemmatizer.git
#   Cloning https://github.com/banglakit/lemmatizer.git to /tmp/pip-req-build-i_cbuol5
#   Running command git clone --filter=blob:none --quiet https://github.com/banglakit/lemmatizer.git /tmp/pip-req-build-i_cbuol5
#   Resolved https://github.com/banglakit/lemmatizer.git to commit f94d8f8dfe06fac70fa151a46069888acffe8870
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: banglakit-lemmatizer
#   Building wheel for banglakit-lemmatizer (setup.py) ... done
#   Created wheel for banglakit-lemmatizer: filename=banglakit_lemmatizer-0.0.1-py3-none-any.whl size=117700 sha256=baa17a0698db0ca8160b908dc66a4037f92e4faf1614b9a6c325f60a2e540b6b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ecj0a3p3/wheels/a8/7c/4d/469b65c3a833f0620db622cb84ef76e2b0519d5efb677b93e7
# Successfully built banglakit-lemmatizer
# Installing collected packages: banglakit-lemmatizer
# Successfully installed banglakit-lemmatizer-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from banglakit.lemmatizer import BengaliLemmatizer

lemmatizer = BengaliLemmatizer()

def lemmatize_tokens(tokens):
    lem_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return lem_tokens

df['lem_tokens'] = df['word_tokens'].apply(lambda x: lemmatize_tokens(x))

# %%
df
# Out:
#           SL   Emotion                                               Text  \
# 0          1   disgust  নির্বাচনের আগের রাতে সুষ্টু শান্তিপূর্ণ ভাবে ভ...
# 1          2   disgust  জনগণ মনের আনন্দে নিজেদের ভোট কাস্ট করে দেশদ্রো...
# 2          3     angry                                   ভেজাল নির্বাচন ।
# 3          4     happy  বিএনপি ও রাজাকার সমর্থকরা হেরে গেলে দেশের জন্য...
# 4          5     angry  সূক্ষ্ম কারচুপি বলে এতদিন একটা কথার কথা ছিল, এ...
# ...      ...       ...                                                ...
# 35995  35996  surprise  ভারতের মতো একটা বিশাল দেশে এত অঙ্গরাজ্য যে সব ...
# 35996  35997  surprise                ২৪, ৫০, এমনকি কারো কারো মতে ৬০ জন।
# 35997  35998  surprise  এদের মধ্য থেকে ২৭ জনকে রাজা বিয়ে দিয়েছিল চন্...
# 35998  35999  surprise  ওয়াকফের শাব্দিক অর্থ কোনো কিছু আটকে রাখা, উৎস...
# 35999  36000  surprise   তৃণমূলের সাবেক মন্ত্রী শুভেন্দু সম্প্রতি মমতা...
#
#                                              word_tokens  \
# 0      [নির্বাচনের, আগের, রাতে, সুষ্টু, শান্তিপূর্ণ, ...
# 1      [জনগণ, মনের, আনন্দে, নিজেদের, ভোট, কাস্ট, করে,...
# 2                                   [ভেজাল, নির্বাচন, ।]
# 3      [বিএনপি, ও, রাজাকার, সমর্থকরা, হেরে, গেলে, দেশ...
# 4      [সূক্ষ্ম, কারচুপি, বলে, এতদিন, একটা, কথার, কথা...
# ...                                                  ...
# 35995  [ভারতের, মতো, একটা, বিশাল, দেশে, এত, অঙ্গরাজ্য...
# 35996  [২৪, ,, ৫০, ,, এমনকি, কারো, কারো, মতে, ৬০, জন, ।]
# 35997  [এদের, মধ্য, থেকে, ২৭, জনকে, রাজা, বিয়ে, দিয়...
# 35998  [ওয়াকফের, শাব্দিক, অর্থ, কোনো, কিছু, আটকে, রা...
# 35999  [তৃণমূলের, সাবেক, মন্ত্রী, শুভেন্দু, সম্প্রতি,...
#
#                                               lem_tokens
# 0      [নির্বাচনের, আগের, রাতে, সুষ্টু, শান্তিপূর্ণ, ...
# 1      [জনগণ, মনের, আনন্দে, নিজেদের, ভোট, কাস্ট, কর, ...
# 2                                   [ভেজাল, নির্বাচন, ।]
# 3      [বিএনপি, ও, রাজাকার, সমর্থকরা, হেরে, যাওয়া, দে...
# 4      [সূক্ষ্ম, কারচুপি, বল, এতদিন, একটা, কথার, কথা,...
# ...                                                  ...
# 35995  [ভারতের, মতো, একটা, বিশাল, দেশে, এত, অঙ্গরাজ্য...
# 35996  [২৪, ,, ৫০, ,, এমনকি, কারো, কারো, মতে, ৬০, জন, ।]
# 35997  [এদের, মধ্য, থেকে, ২৭, জনকে, রাজা, বিয়ে, দিয়...
# 35998  [ওয়াকফের, শাব্দিক, অর্থ, কোনো, কিছু, আটকে, রা...
# 35999  [তৃণমূলের, সাবেক, মন্ত্রী, শুভেন্দু, সম্প্রতি,...
#
# [36000 rows x 5 columns]

# %%
def lemmatize_tokens_join(tokens):
    lem_text = ' '.join(tokens)
    return lem_text

df['Lemm_Text'] = df['lem_tokens'].apply(lambda x: lemmatize_tokens_join(x))

# %%
df
# Out:
#           SL   Emotion                                               Text  \
# 0          1   disgust  নির্বাচনের আগের রাতে সুষ্টু শান্তিপূর্ণ ভাবে ভ...
# 1          2   disgust  জনগণ মনের আনন্দে নিজেদের ভোট কাস্ট করে দেশদ্রো...
# 2          3     angry                                   ভেজাল নির্বাচন ।
# 3          4     happy  বিএনপি ও রাজাকার সমর্থকরা হেরে গেলে দেশের জন্য...
# 4          5     angry  সূক্ষ্ম কারচুপি বলে এতদিন একটা কথার কথা ছিল, এ...
# ...      ...       ...                                                ...
# 35995  35996  surprise  ভারতের মতো একটা বিশাল দেশে এত অঙ্গরাজ্য যে সব ...
# 35996  35997  surprise                ২৪, ৫০, এমনকি কারো কারো মতে ৬০ জন।
# 35997  35998  surprise  এদের মধ্য থেকে ২৭ জনকে রাজা বিয়ে দিয়েছিল চন্...
# 35998  35999  surprise  ওয়াকফের শাব্দিক অর্থ কোনো কিছু আটকে রাখা, উৎস...
# 35999  36000  surprise   তৃণমূলের সাবেক মন্ত্রী শুভেন্দু সম্প্রতি মমতা...
#
#                                              word_tokens  \
# 0      [নির্বাচনের, আগের, রাতে, সুষ্টু, শান্তিপূর্ণ, ...
# 1      [জনগণ, মনের, আনন্দে, নিজেদের, ভোট, কাস্ট, করে,...
# 2                                   [ভেজাল, নির্বাচন, ।]
# 3      [বিএনপি, ও, রাজাকার, সমর্থকরা, হেরে, গেলে, দেশ...
# 4      [সূক্ষ্ম, কারচুপি, বলে, এতদিন, একটা, কথার, কথা...
# ...                                                  ...
# 35995  [ভারতের, মতো, একটা, বিশাল, দেশে, এত, অঙ্গরাজ্য...
# 35996  [২৪, ,, ৫০, ,, এমনকি, কারো, কারো, মতে, ৬০, জন, ।]
# 35997  [এদের, মধ্য, থেকে, ২৭, জনকে, রাজা, বিয়ে, দিয়...
# 35998  [ওয়াকফের, শাব্দিক, অর্থ, কোনো, কিছু, আটকে, রা...
# 35999  [তৃণমূলের, সাবেক, মন্ত্রী, শুভেন্দু, সম্প্রতি,...
#
#                                               lem_tokens  \
# 0      [নির্বাচনের, আগের, রাতে, সুষ্টু, শান্তিপূর্ণ, ...
# 1      [জনগণ, মনের, আনন্দে, নিজেদের, ভোট, কাস্ট, কর, ...
# 2                                   [ভেজাল, নির্বাচন, ।]
# 3      [বিএনপি, ও, রাজাকার, সমর্থকরা, হেরে, যাওয়া, দে...
# 4      [সূক্ষ্ম, কারচুপি, বল, এতদিন, একটা, কথার, কথা,...
# ...                                                  ...
# 35995  [ভারতের, মতো, একটা, বিশাল, দেশে, এত, অঙ্গরাজ্য...
# 35996  [২৪, ,, ৫০, ,, এমনকি, কারো, কারো, মতে, ৬০, জন, ।]
# 35997  [এদের, মধ্য, থেকে, ২৭, জনকে, রাজা, বিয়ে, দিয়...
# 35998  [ওয়াকফের, শাব্দিক, অর্থ, কোনো, কিছু, আটকে, রা...
# 35999  [তৃণমূলের, সাবেক, মন্ত্রী, শুভেন্দু, সম্প্রতি,...
#
#                                                Lemm_Text
# 0      নির্বাচনের আগের রাতে সুষ্টু শান্তিপূর্ণ ভাবে ভ...
# 1      জনগণ মনের আনন্দে নিজেদের ভোট কাস্ট কর দেশদ্রোহ...
# 2                                       ভেজাল নির্বাচন ।
# 3      বিএনপি ও রাজাকার সমর্থকরা হেরে যাওয়া দেশের জন্...
# 4      সূক্ষ্ম কারচুপি বল এতদিন একটা কথার কথা ছিল , এ...
# ...                                                  ...
# 35995  ভারতের মতো একটা বিশাল দেশে এত অঙ্গরাজ্য -PRON-...
# 35996              ২৪ , ৫০ , এমনকি কারো কারো মতে ৬০ জন ।
# 35997  এদের মধ্য থেকে ২৭ জনকে রাজা বিয়ে দিয়েছিল চন্...
# 35998  ওয়াকফের শাব্দিক অর্থ কোনো কিছু আটকে রাখ , উৎস...
# 35999  তৃণমূলের সাবেক মন্ত্রী শুভেন্দু সম্প্রতি মমতার...
#
# [36000 rows x 6 columns]

# %%
text = df['Lemm_Text'].values.tolist()
label = df['Emotion'].tolist()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(text , label, test_size=0.2, random_state=42)

# %%
import ktrain
from ktrain import text
MODEL_NAME = 'xlm-roberta-base'
t = text.Transformer(MODEL_NAME, maxlen=500)
# Out:
# Downloading config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/512 [00:00<?, ?B/s]
# Downloading tf_model.h5:   0%|          | 0.00/1.89G [00:00<?, ?B/s]

# %%
trn = t.preprocess_train(X_train, y_train)
val = t.preprocess_test(X_test, y_test)
# Out:
# preprocessing train...
# language: bn
# train sequence lengths:
# 	mean : 18
# 	95percentile : 49
# 	99percentile : 75
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Is Multi-Label? False
# preprocessing test...
# language: bn
# test sequence lengths:
# 	mean : 18
# 	95percentile : 48
# 	99percentile : 75
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
model = t.get_classifier()

# %%
learner = ktrain.get_learner(model, train_data=trn, val_data=val, batch_size=12)

# %%
history = learner.fit_onecycle(2e-5, 5)
# Out:
# begin training using onecycle policy with max lr of 2e-05...
# Epoch 1/5
# 2400/2400 [==============================] - 2251s 924ms/step - loss: 1.6267 - accuracy: 0.3240 - val_loss: 1.4476 - val_accuracy: 0.4199
# Epoch 2/5
# 2400/2400 [==============================] - 2212s 922ms/step - loss: 1.3722 - accuracy: 0.4695 - val_loss: 1.2878 - val_accuracy: 0.4613
# Epoch 3/5
# 2400/2400 [==============================] - 2209s 921ms/step - loss: 1.0069 - accuracy: 0.6353 - val_loss: 0.7580 - val_accuracy: 0.7507
# Epoch 4/5
# 2400/2400 [==============================] - 2212s 921ms/step - loss: 0.5890 - accuracy: 0.8040 - val_loss: 0.5773 - val_accuracy: 0.8189
# Epoch 5/5
# 2400/2400 [==============================] - 2213s 922ms/step - loss: 0.3716 - accuracy: 0.8769 - val_loss: 0.5327 - val_accuracy: 0.8453

# %%
learner.validate(class_names=t.get_classes())
# Out:
# 225/225 [==============================] - 158s 684ms/step
#               precision    recall  f1-score   support
#
#        angry       0.83      0.84      0.83      1226
#      disgust       0.83      0.88      0.86      1188
#         fear       0.90      0.89      0.89      1129
#        happy       0.89      0.88      0.89      1246
#          sad       0.76      0.70      0.73      1244
#     surprise       0.85      0.89      0.87      1167
#
#     accuracy                           0.85      7200
#    macro avg       0.85      0.85      0.85      7200
# weighted avg       0.84      0.85      0.84      7200
# array([[1024,   65,   22,   20,   67,   28],
#        [  55, 1042,    9,   21,   44,   17],
#        [  22,   12, 1010,   12,   47,   26],
#        [  26,   10,   12, 1096,   61,   41],
#        [  93,   89,   62,   62,  871,   67],
#        [  14,   30,   13,   17,   50, 1043]])

# %%
def PlotGraph(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'g', label='Training acc')
    plt.plot(x, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'g', label='Training loss')
    plt.plot(x, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

# %%
PlotGraph(history)
